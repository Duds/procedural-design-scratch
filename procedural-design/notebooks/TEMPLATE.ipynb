# %% [markdown]
# # EXPERIMENT_NAME
#
# **Date:** YYYY/MM/DD
#
# ## Overview
#
# Description of the experiment, goals, and expected outcomes.
#
# ## Objectives
#
# - Goal 1
# - Goal 2
# - Goal 3
#
# ## Methodology
#
# Brief description of the approach.

# %% [markdown]
# ## Setup and Imports
#
# Configure notebook paths and import required modules.

# %%
# Standard library
import sys
from pathlib import Path

# Set up notebook paths to enable src/ imports
from src.utils.notebook import setup_notebook_paths, print_notebook_setup_info

project_root = setup_notebook_paths()
print_notebook_setup_info()

# %%
# Third-party libraries
import numpy as np
import matplotlib.pyplot as plt
import trimesh

# Optional: Check for GPU acceleration
from src.utils.notebook import check_optional_import
TAICHI_AVAILABLE = check_optional_import('taichi', 'taichi')

# Project modules
from src.algorithms.gray_scott import GrayScottSimulator, GrayScottConfig
# Add other imports as needed

print("✅ All imports successful!")
